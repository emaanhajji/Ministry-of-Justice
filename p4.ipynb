# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re

# %%
df = pd.read_csv('court_project', index_col=[0]) #read the data 

df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0     1640298117-87  https://sjp.moj.gov.sa/Filter?isFilterButtonCl...
# 1     1640297824-62  https://sjp.moj.gov.sa/Filter?isFilterButtonCl...
# 2     1640298107-86  https://sjp.moj.gov.sa/Filter?isFilterButtonCl...
# 3     1640297908-69  https://sjp.moj.gov.sa/Filter?isFilterButtonCl...
# 4     1640297731-53  https://sjp.moj.gov.sa/Filter?isFilterButtonCl...
#
#                            links  \
# 0  القضية رقم  ٤٦٤٦ لعام ١٤٤٢ هـ
# 1  القضية رقم  ٦٩٥٨ لعام ١٤٤٢ هـ
# 2  القضية رقم  ٦٦٠٧ لعام ١٤٤٢ هـ
# 3  القضية رقم  ٤٣٣١ لعام ١٤٤٢ هـ
# 4  القضية رقم  ٩٣٩٩ لعام ١٤٤١ هـ
#
#                                          links-href  \
# 0  https://sjp.moj.gov.sa/Filter/AhkamDetails/38991
# 1  https://sjp.moj.gov.sa/Filter/AhkamDetails/38903
# 2  https://sjp.moj.gov.sa/Filter/AhkamDetails/38992
# 3  https://sjp.moj.gov.sa/Filter/AhkamDetails/39268
# 4  https://sjp.moj.gov.sa/Filter/AhkamDetails/38987
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 213
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      214 non-null    object
#  1   web-scraper-start-url  214 non-null    object
#  2   links                  102 non-null    object
#  3   links-href             102 non-null    object
#  4   court                  192 non-null    object
#  5   case_number            102 non-null    object
#  6   case_date              102 non-null    object
#  7   appellate_court        89 non-null     object
#  8   appellate_id           89 non-null     object
#  9   appellate_date         89 non-null     object
#  10  region                 116 non-null    object
#  11  city                   192 non-null    object
#  12  judgment_text          192 non-null    object
#  13  appeal                 89 non-null     object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'links', 'links-href',
#        'court', 'case_number', 'case_date', 'appellate_court', 'appellate_id',
#        'appellate_date', 'region', 'city', 'judgment_text', 'appeal', 'pages',
#        'pages-href', 'links0', 'links0-href', 'court_id', 'court_date',
#        'appeal_court', 'appeal_id', 'appeal_date', 'appeal_text', 'links1',
#        'links1-href', 'القضايا', 'القضايا-href', 'نص الحكم', 'الصفحات',
#        'الصفحات-href'],
#       dtype='object')

# %%
df.shape
# Out:
# (214, 31)

# %%
import requests
import nltk
from nltk.corpus import stopwords
 
# Making a get request
response = requests.get('https://api.github.com')

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk; nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Techno
# [nltk_data]    |     Link\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to C:\Users\Techno
# [nltk_data]    |     Link\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\Techno Link\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to C:\Users\Techno
# [nltk_data]    |     Link\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to C:\Users\Techno
# [nltk_data]    |     Link\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# ...

# %%
stop_words = list(set(stopwords.words('arabic')))
print(stop_words)
# Out:
# ['أولئك', 'هاتان', 'ذواتي', 'ذلكما', 'ماذا', 'أخذ', 'ثلاثين', 'إي', 'تسع', 'حدَث', 'ءَ', 'كأيّ', 'عليك', 'هَذِي', 'بيد', 'م', 'تفعلان', 'بين', 'كان', 'ش', 'هاته', 'هذه', 'أما', 'أغسطس', 'ولو', 'حار', 'بلى', 'غين', 'صراحة', 'ألا', 'نحن', 'تفعلون', 'ما انفك', 'رويدك', 'ث', 'تلكما', 'إيه', 'ج', 'تانِ', 'كثيرا', 'نيسان', 'فرادى', 'حتى', 'جويلية', 'تجاه', 'هيت', 'وَيْ', 'مئتان', 'ص', 'ساء', 'فإن', 'عاشر', 'كم', 'تَيْنِ', 'عليه', 'ين', 'لات', 'ذلكن', 'سابع', 'لن', 'أربعاء', 'بهن', 'أين', 'تحوّل', 'مكانكنّ', 'إى', 'أنتما', 'ذينك', 'أي', 'تفعلين', 'صدقا', 'فلان', 'اللذان', 'والذي', 'أخبر', 'عل', 'لست', 'بضع', 'آهاً', 'هلا', 'كأنما', 'منذ', 'ما أفعله', 'أو', 'اللتيا', 'أمام', 'جيم', 'أقل', 'أنتن', 'أنى', 'خميس', 'وراءَك', 'ثلاثاء', 'تموز', 'الآن', 'ستين', 'إياكم', 'مادام', 'ذِي', 'له', 'راء', 'ميم', 'بنا', 'عين', 'بعض', 'ثامن', 'غداة', 'ومن', 'يورو', 'سبعون', 'أمّا', 'بعدا', 'أوشك', 'مكانكم', 'بكم', 'مذ', 'متى', 'س', 'حيث', 'عسى', 'كيفما', 'سبعة', 'خلافا', 'منها', 'ما برح', 'هاكَ', 'غادر', 'ن
# ...

# %%
arabic_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ''' # define arabic punctuations

def clean_text(df):

 # text = re.sub("[a-zA-Z]", " ", df) # remove english letters
  #text = re.sub('\n', ' ', df) # remove \n from text
  #text = re.sub(r'\d+', '', text) #remove number
 
 # text = df.translate(str.maketrans('','', arabic_punctuations)) # remove punctuation
  text = ' '.join([word for word in df.split() if word not in stopwords.words("arabic")]) # remove stop word
  #text = re.sub(' +', ' ',df) # remove extra space
  #text = df.strip() #remove whitespaces

  return df
